# %%
import pandas as pd

df1 = pd.read_csv('/Users/gufran/Developer/Projects/AI/ArabicAbstractiveSummarization/data/train1_processed.csv')
df1.drop(columns=["dataset", "filename", "length", "offset", "published", "section", "subdomain"], inplace=True)
# Out:
#                                      headline  \
# 0   المصري فؤاد الطاهر بطل للشطرنج الديناميكي
# 1  حملة انتخابية محمومة قبل "الثلاثاء الكبير"
# 2              55% من نزلاء «الأحداث» مواطنون
# 3           مركز متخصص في الكلى بمستشفى خليفة
# 4          تأهيل ضحايا حوادث المرور في أبوظبي
#
#                                                 text  \
# 0  اختتمت مساء أول من أمس نهائيات بطولة الإمارات ...
# 1  مينيابوليس (الولايات المتحدة) 3-2-2008 (ا ف ب)...
# 2  أفاد مصدر في شرطة أبوظبي بأن نحو 700 طفل يتواف...
# 3  قال استشاري أمراض الكلى في مدينة الشيخ خليفة ا...
# 4  بدأت القيادة العامة لشرطة أبوظبي التنسيق لإنشا...
#
#                                                  url  \
# 0  https://www.emaratalyoum.com/local-section/200...
# 1  https://www.emaratalyoum.com/local-section/200...
# 2  https://www.emaratalyoum.com/local-section/200...
# 3  https://www.emaratalyoum.com/local-section/200...
# 4  https://www.emaratalyoum.com/local-section/200...
#
# ...

# %%
df1.head()
# Out:
#                                      headline  \
# 0   المصري فؤاد الطاهر بطل للشطرنج الديناميكي
# 1  حملة انتخابية محمومة قبل "الثلاثاء الكبير"
# 2              55% من نزلاء «الأحداث» مواطنون
# 3           مركز متخصص في الكلى بمستشفى خليفة
# 4          تأهيل ضحايا حوادث المرور في أبوظبي
#
#                                                 text  \
# 0  اختتمت مساء أول من أمس نهائيات بطولة الإمارات ...
# 1  مينيابوليس (الولايات المتحدة) 3-2-2008 (ا ف ب)...
# 2  أفاد مصدر في شرطة أبوظبي بأن نحو 700 طفل يتواف...
# 3  قال استشاري أمراض الكلى في مدينة الشيخ خليفة ا...
# 4  بدأت القيادة العامة لشرطة أبوظبي التنسيق لإنشا...
#
#                                                  url  \
# 0  https://www.emaratalyoum.com/local-section/200...
# 1  https://www.emaratalyoum.com/local-section/200...
# 2  https://www.emaratalyoum.com/local-section/200...
# 3  https://www.emaratalyoum.com/local-section/200...
# 4  https://www.emaratalyoum.com/local-section/200...
#
# ...

# %%
print(df1.iloc[0].url)
print()
print(df1.iloc[0].headline)
print()
print(df1.iloc[0].text)
print()
print(df1.iloc[0].text_preprocessed)
# Out:
# https://www.emaratalyoum.com/local-section/2008-02-03-1.192514
#
# المصري فؤاد الطاهر بطل للشطرنج الديناميكي
#
# اختتمت مساء أول من أمس نهائيات بطولة الإمارات للشطرنج الديناميكي المفتوحة التي نظمها اتحاد الإمارات للشطرنج بمقر نادي دبي للشطرنج والثقافة حيث توج الأستاذ الدولي المصري فؤاد الطاهر بطلا للمسابقة برصيد 6 نقاط من 7 جولات.
#
# اختتم +ت مساء أول من أمس نهائي +ات بطول +ة ال+ إمار +ات ل+ ال+ شطرنج ال+ ديناميكي ال+ مفتوح +ة التي نظم +ها اتحاد ال+ إمار +ات ل+ ال+ شطرنج ب+ مقر نادي دبي ل+ ال+ شطرنج و+ ال+ ثقاف +ة حيث توج ال+ أستاذ ال+ دولي ال+ مصري فؤاد ال+ طاهر بطل +ا ل+ ال+ مسابق +ة ب+ رصيد 6 نقاط من 7 جول +ات .

# %%
df2 = pd.read_csv('/Users/gufran/Developer/Projects/AI/ArabicAbstractiveSummarization/data/extractive_data.csv')
df2.drop(columns=["Unnamed: 0"], inplace=True)
df2.head()
# Out:
#                                              Article  \
# 0  اصدر معالي يحيى بن سعود السليمي وزير التربية و...
# 1  اتجاه إيجابي من جانبه أكد د \n\n عبد الصبور شا...
# 2  كثيرا ما شعرت بنقص كبير في التعريف بالفكر الاب...
# 3  الأيام دول بين الناس تعبر عبر الزمان والمكان و...
# 4  سباع السعدي : عمان تزخر بتاريخ بحري قديم والشب...
#
#                                            Summary_1  \
# 0  واما بخصوص القرار الوزاري الثاني فقد نص على أن...
# 1  وأضاف أنه يجب أن نعلم أن أوروبا وأميركا يعلمون...
# 2  ومن النماذج الأولى في التعريف ببعض المصطلحات ي...
# 3  أما النظرة السطحية العابرة دون النظر والإمعان ...
# 4  اليحمدي : المسابقات أفرزت عن جيل من الشباب في ...
#
#                                    Article_processed
# 0  أصدر معالي يحيى بن سعود ال+ سليمي وزير ال+ ترب...
# 1  اتجاه إيجابي من جانب +ه أكد د عبد ال+ صبور شاه...
# 2  كثير +ا ما شعر +ت ب+ نقص كبير في ال+ تعريف ب+ ...
# 3  ال+ أيام دول بين ال+ ناس تعبر عبر ال+ زمان و+ ...
# 4  سباع ال+ سعدي : عمان تزخر ب+ تاريخ بحري قديم و...

# %%
print(df2.iloc[0].Article)
# Out:
# اصدر معالي يحيى بن سعود السليمي وزير التربية والتعليم قرارين وزاريين برقم ( 1582004 م ) و ( 1592004 م ) بخصوص نظام تقويم اداء الطلاب في مدارس التعليم الاساسي والعام وبشأن لجان متابعة تنفيذ التقويم التربوي المطور بمدارس التعليم الاساسي والعام ونص القرار الاول على أن يطبق نظام تقويم اداء الطلاب المرفق في مدارس التعليم الاساسي والتعليم العام اعتبارا من العام الدراسي 20042005 م وعلى الجهات المعنية بالوزارة اتخاذ الاجراءات والتدابير اللازمة لتنفيذ النظام المشار اليه ويلغى كل ما يخالف هذا القرار او يتعارض مع احكامه ويعمل بهذا القرار من تاريخ صدوره
#
# ...

# %%
print(df2.iloc[0].Summary_1)
# Out:
# واما بخصوص القرار الوزاري الثاني فقد نص على أن تشكل لجان متابعة متطلبات تنفيذ التقويم التربوي المطور بمدارس التعليم الاساسي والتعليم العام على النحو التالي لجنة المتابعة الرئيسية برئاسة وكيل الوزارة للتعليم والمناهج وعضوية كل من مستشار الوزير للتقويم التربوي ونائب مدير عام المديرية العامة للمناهج ومدير دائرة التقويم التربوي ومدير دائرة الاشراف التربوي بالمديرية العامة للتعليم ونائب مدير دائرة التقويم التربوي لشؤون التقويم التربوي عضوا ومقررا للجنة وتختص هذه اللجنة بالاشراف العام على تنفيذ القرار الوزاري رقم ( 1582004 م ) بنظام تقويم اداء الطلاب في مدارس التعليم الاساسي والتعليم العام واتخاذ كافة الاجراءات والتدابير اللازمة لذلك بالتنسيق والمتابعة مع لجان المناطق التعليمية وكافة الجهات المعنية وتختص اللجنة بصفة خاصة بالاشراف على اعداد دليل شامل للتقويم التربوي المطور وكذلك التأكد من اعداد المواصفات اللازمة للتقويم الختامي والتقويم المستمر لكل مادة دراسية الى جانب متابعة اعداد البطاقات التقويمية والسجلات وايضا متابعة تزويد المدارس بجميع متطلبات التقويم التربوي المطور وكذلك الاشراف على 
# ...
